# %% [markdown]
# ### Overaying camera pictures with SCANDI wind fields

# %%
import moviepy.editor as mpe
import matplotlib.pyplot as plt

# %%
clip1 = mpe.VideoFileClip('SCANDI_movie.mp4')
clip2 = mpe.VideoFileClip(r"C:\Users\rifat\OneDrive - University College London\Rifat's PC\Internship 2021\FPI\FPI-Winds\KHO_21-22Dec2014-ASC\KHO_21Dec2014.mp4").set_opacity(0.5).set_position(-5,3)
full_clip = mpe.CompositeVideoClip([clip1,clip2])
full_clip.write_videofile("my_result.mp4")
# Out:
# t:   0%|                                                                             | 0/399 [00:00<?, ?it/s, now=None]
# Moviepy - Building video my_result.mp4.
# Moviepy - Writing video my_result.mp4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b13354c22d05> in <module>
#       2 clip2 = mpe.VideoFileClip(r"C:\Users\rifat\OneDrive - University College London\Rifat's PC\Internship 2021\FPI\FPI-Winds\KHO_21-22Dec2014-ASC\KHO_21Dec2014.mp4").set_opacity(0.5).set_position(-5,3)
#       3 full_clip = mpe.CompositeVideoClip([clip1,clip2])
# ----> 4 full_clip.write_videofile("my_result.mp4")
#
# <decorator-gen-181> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ...

# %%
plt.plot(r"C:\Users\rifat\OneDrive - University College London\Rifat's PC\Internship 2021\FPI\FPI-Winds\KHO_21-22Dec2014-ASC\KHO_22Dec14_11.58.11.jpeg")
